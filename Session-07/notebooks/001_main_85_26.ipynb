# %%
import os
os.chdir("drive/My Drive/EVA/Session07/cifar10/Session-07")

# %%
# !ls
# Out:
# checkpoints  dataset  main_01.ipynb  networks	  README.md
# configs      images   main.py	     notebooks	  requirements.txt
# data	     losses   models	     __pycache__  utils.py

# %%
from __future__ import print_function
import json
import os

curr_dir = os.curdir

# %%
config_file = os.path.join(curr_dir,"configs/cifar10_config.json")

# %%
from main import TrainNetwork
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
trainNet = TrainNetwork(config_file)
# Out:
# Number of GPU's available : 1
# GPU device name : Tesla P4
# Files already downloaded and verified
# Files already downloaded and verified
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             432
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#            Dropout-4           [-1, 16, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           4,608
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#               ReLU-7           [-1, 32, 32, 32]               0
#            Dropout-8           [-1, 32, 32, 32]               0
#             Conv2d-9           [-1, 64, 32, 32]          18,432
#       BatchNorm2d-10           [-1, 64, 32, 32]             128
#              ReLU-11           [-1, 64, 32, 32]               0
#            Conv2d-12           [-1, 64, 32, 32]             640
#            Conv2d-13           [-1, 32, 32, 32]           2,080
# depthwise_separable_conv-14           [-1, 32, 32, 32]               0
#       BatchNorm2d-15           [-1, 32, 32, 32]              64
#              ReLU-16           [-1, 32, 32, 32]               0
#           Dropout-17           [-1, 32, 32, 32]               0
#         MaxPool2d-18           [-1, 32, 16, 16]               0
#            Conv2d-19           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#              ReLU-21           [-1, 64, 16, 16]               0
#           Dropout-22           [-1, 64, 16, 16]               0
#            Conv2d-23           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-24           [-1, 64, 16, 16]             128
#              ReLU-25           [-1, 64, 16, 16]               0
#            Conv2d-26           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-27           [-1, 64, 16, 16]             128
#              ReLU-28           [-1, 64, 16, 16]               0
#            Conv2d-29           [-1, 64, 16, 16]             640
#            Conv2d-30           [-1, 64, 16, 16]           4,160
# depthwise_separable_conv-31           [-1, 64, 16, 16]               0
#       BatchNorm2d-32           [-1, 64, 16, 16]             128
#              ReLU-33           [-1, 64, 16, 16]               0
#         MaxPool2d-34             [-1, 64, 8, 8]               0
#            Conv2d-35             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-36             [-1, 64, 8, 8]             128
#              ReLU-37             [-1, 64, 8, 8]               0
#           Dropout-38             [-1, 64, 8, 8]               0
#            Conv2d-39             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-40             [-1, 64, 8, 8]             128
#              ReLU-41             [-1, 64, 8, 8]               0
#           Dropout-42             [-1, 64, 8, 8]               0
#            Conv2d-43            [-1, 128, 6, 6]          73,728
#       BatchNorm2d-44            [-1, 128, 6, 6]             256
#              ReLU-45            [-1, 128, 6, 6]               0
#         AvgPool2d-46            [-1, 128, 1, 1]               0
#            Conv2d-47             [-1, 64, 1, 1]           8,256
#            Linear-48                   [-1, 10]             650
# ================================================================
# Total params: 262,394
# Trainable params: 262,394
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 7.08
# Params size (MB): 1.00
# Estimated Total Size (MB): 8.09
# ----------------------------------------------------------------
# /content/drive/My Drive/EVA/Session07/cifar10/Session-07/networks/cifar10net.py:108: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)

# %%
trainNet.visulaize_dataset()

# %%
trainNet.start()
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# EPOCH : 1
# /content/drive/My Drive/EVA/Session07/cifar10/Session-07/networks/cifar10net.py:108: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# loss=3.7565598487854004 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.48it/s]
#   TRAIN avg loss: 0.0648 train acc: 50.9040
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 1.2068 test acc: 57.7000
#
#
# EPOCH : 2
# loss=4.419995307922363 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.01it/s]
#   TRAIN avg loss: 0.0511 train acc: 67.2240
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.9160 test acc: 68.1900
#
#
# EPOCH : 3
# loss=3.0821690559387207 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.93it/s]
#   TRAIN avg loss: 0.0458 train acc: 72.5880
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.8389 test acc: 70.6300
#
#
# EPOCH : 4
# loss=2.295958995819092 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.16it/s]
#   TRAIN avg loss: 0.0424 train acc: 75.6080
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.7988 test acc: 72.0300
#
#
# EPOCH : 5
# loss=3.0392160415649414 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.69it/s]
#   TRAIN avg loss: 0.0400 train acc: 77.5780
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.7637 test acc: 73.8200
#
#
# EPOCH : 6
# loss=3.1108508110046387 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.16it/s]
#   TRAIN avg loss: 0.0382 train acc: 78.7340
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.7437 test acc: 74.5100
#
#
# EPOCH : 7
# loss=1.8444743156433105 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.88it/s]
#   TRAIN avg loss: 0.0324 train acc: 84.8380
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4812 test acc: 83.3100
#
#
# EPOCH : 8
# loss=2.3280656337738037 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.33it/s]
#   TRAIN avg loss: 0.0308 train acc: 86.3600
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4607 test acc: 83.8000
#
#
# EPOCH : 9
# loss=2.0078139305114746 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.13it/s]
#   TRAIN avg loss: 0.0298 train acc: 86.9600
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4662 test acc: 83.8700
#
#
# EPOCH : 10
# loss=2.609670639038086 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.33it/s]
#   TRAIN avg loss: 0.0291 train acc: 87.5280
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4527 test acc: 84.4200
#
#
# EPOCH : 11
# loss=1.7806212902069092 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.85it/s]
#   TRAIN avg loss: 0.0283 train acc: 88.0820
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4563 test acc: 84.4300
#
#
# EPOCH : 12
# loss=2.9607510566711426 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.02it/s]
#   TRAIN avg loss: 0.0278 train acc: 88.3540
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4528 test acc: 84.4700
#
#
# EPOCH : 13
# loss=1.5902681350708008 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.09it/s]
#   TRAIN avg loss: 0.0266 train acc: 89.6040
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4398 test acc: 84.8700
#
#
# EPOCH : 14
# loss=1.7403051853179932 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.05it/s]
#   TRAIN avg loss: 0.0263 train acc: 89.8120
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4373 test acc: 84.9400
#
#
# EPOCH : 15
# loss=2.3170056343078613 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.59it/s]
#   TRAIN avg loss: 0.0261 train acc: 90.2240
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4376 test acc: 85.0200
#
#
# EPOCH : 16
# loss=2.73722767829895 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.30it/s]
#   TRAIN avg loss: 0.0260 train acc: 90.2360
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4396 test acc: 84.9000
#
#
# EPOCH : 17
# loss=1.7514047622680664 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.48it/s]
#   TRAIN avg loss: 0.0258 train acc: 90.5440
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4396 test acc: 85.0700
#
#
# EPOCH : 18
# loss=1.6322832107543945 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.11it/s]
#   TRAIN avg loss: 0.0258 train acc: 90.4540
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4397 test acc: 85.1200
#
#
# EPOCH : 19
# loss=2.39475679397583 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.33it/s]
#   TRAIN avg loss: 0.0257 train acc: 90.4660
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4410 test acc: 84.9100
#
#
# EPOCH : 20
# loss=1.5608081817626953 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.32it/s]
#   TRAIN avg loss: 0.0255 train acc: 90.8420
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4398 test acc: 85.1000
#
#
# EPOCH : 21
# loss=2.0979604721069336 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.18it/s]
#   TRAIN avg loss: 0.0256 train acc: 90.6420
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4364 test acc: 85.1400
#
#
# EPOCH : 22
# loss=2.110856294631958 batch_id=781: 100%|██████████| 782/782 [00:29<00:00, 26.45it/s]
#   TRAIN avg loss: 0.0256 train acc: 90.6480
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4384 test acc: 85.1300
#
#
# EPOCH : 23
# loss=1.2687528133392334 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.53it/s]
#   TRAIN avg loss: 0.0256 train acc: 90.6020
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4374 test acc: 85.0100
#
#
# EPOCH : 24
# loss=2.0725629329681396 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.24it/s]
#   TRAIN avg loss: 0.0256 train acc: 90.5640
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4394 test acc: 85.0000
#
#
# EPOCH : 25
# loss=2.7805824279785156 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.41it/s]
#   TRAIN avg loss: 0.0255 train acc: 90.6920
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4376 test acc: 85.1400
#
#
# EPOCH : 26
# loss=1.925922155380249 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.47it/s]
#   TRAIN avg loss: 0.0256 train acc: 90.6160
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4363 test acc: 85.2500
#
#
# EPOCH : 27
# loss=1.169597864151001 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.77it/s]
#   TRAIN avg loss: 0.0255 train acc: 90.6700
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4369 test acc: 85.1200
#
#
# EPOCH : 28
# loss=2.406453847885132 batch_id=781: 100%|██████████| 782/782 [00:27<00:00, 28.52it/s]
#   TRAIN avg loss: 0.0255 train acc: 90.6560
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4387 test acc: 85.2600
#
#
# EPOCH : 29
# loss=2.3336641788482666 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.85it/s]
#   TRAIN avg loss: 0.0256 train acc: 90.4400
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4367 test acc: 85.2200
#
#
# EPOCH : 30
# loss=1.5094695091247559 batch_id=781: 100%|██████████| 782/782 [00:28<00:00, 27.00it/s]
#   TRAIN avg loss: 0.0255 train acc: 90.6000
#   TEST avg loss: 0.4392 test acc: 85.2100

# %%
from main import PostAnalysis

# %%
a = PostAnalysis(config_file)
# Out:
# Number of GPU's available : 1
# GPU device name : Tesla P4
# Files already downloaded and verified
# Files already downloaded and verified
# /content/drive/My Drive/EVA/Session07/cifar10/Session-07/networks/cifar10net.py:108: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             432
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#            Dropout-4           [-1, 16, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           4,608
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#               ReLU-7           [-1, 32, 32, 32]               0
#            Dropout-8           [-1, 32, 32, 32]               0
#             Conv2d-9           [-1, 64, 32, 32]          18,432
#       BatchNorm2d-10           [-1, 64, 32, 32]             128
#              ReLU-11           [-1, 64, 32, 32]               0
#            Conv2d-12           [-1, 64, 32, 32]             640
#            Conv2d-13           [-1, 32, 32, 32]           2,080
# depthwise_separable_conv-14           [-1, 32, 32, 32]               0
#       BatchNorm2d-15           [-1, 32, 32, 32]              64
#              ReLU-16           [-1, 32, 32, 32]               0
#           Dropout-17           [-1, 32, 32, 32]               0
#         MaxPool2d-18           [-1, 32, 16, 16]               0
#            Conv2d-19           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#              ReLU-21           [-1, 64, 16, 16]               0
#           Dropout-22           [-1, 64, 16, 16]               0
#            Conv2d-23           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-24           [-1, 64, 16, 16]             128
#              ReLU-25           [-1, 64, 16, 16]               0
#            Conv2d-26           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-27           [-1, 64, 16, 16]             128
#              ReLU-28           [-1, 64, 16, 16]               0
#            Conv2d-29           [-1, 64, 16, 16]             640
#            Conv2d-30           [-1, 64, 16, 16]           4,160
# depthwise_separable_conv-31           [-1, 64, 16, 16]               0
#       BatchNorm2d-32           [-1, 64, 16, 16]             128
#              ReLU-33           [-1, 64, 16, 16]               0
#         MaxPool2d-34             [-1, 64, 8, 8]               0
#            Conv2d-35             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-36             [-1, 64, 8, 8]             128
#              ReLU-37             [-1, 64, 8, 8]               0
#           Dropout-38             [-1, 64, 8, 8]               0
#            Conv2d-39             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-40             [-1, 64, 8, 8]             128
#              ReLU-41             [-1, 64, 8, 8]               0
#           Dropout-42             [-1, 64, 8, 8]               0
#            Conv2d-43            [-1, 128, 6, 6]          73,728
#       BatchNorm2d-44            [-1, 128, 6, 6]             256
#              ReLU-45            [-1, 128, 6, 6]               0
#         AvgPool2d-46            [-1, 128, 1, 1]               0
#            Conv2d-47             [-1, 64, 1, 1]           8,256
#            Linear-48                   [-1, 10]             650
# ================================================================
# Total params: 262,394
# Trainable params: 262,394
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 7.08
# Params size (MB): 1.00
# Estimated Total Size (MB): 8.09
# ----------------------------------------------------------------

# %%
a.show_validation_graph()

# %%
a.show_misclassified_images()

# %%
a.show_per_class_accuracy()
# Out:
# /content/drive/My Drive/EVA/Session07/cifar10/Session-07/networks/cifar10net.py:108: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# plane		85.599998
# car		92.000000
# bird		73.900002
# cat		68.500000
# deer		81.500000
# dog		76.099998
# frog		86.699997
# horse		86.500000
# ship		89.699997
# truck		90.099998
