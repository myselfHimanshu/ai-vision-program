# %%
import os
os.chdir("drive/My Drive/EVA/Session07/cifar10/Session-07")

# %%
# !ls
# Out:
# 002-main_85-84.ipynb  data     losses	networks     README.md
# checkpoints	      dataset  main.py	notebooks    requirements.txt
# configs		      images   models	__pycache__  utils.py

# %%
from __future__ import print_function
import json
import os

curr_dir = os.curdir

# %%
config_file = os.path.join(curr_dir,"configs/cifar10_config.json")

# %%
from main import TrainNetwork
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
trainNet = TrainNetwork(config_file)
# Out:
# Number of GPU's available : 1
# GPU device name : Tesla P4
# Files already downloaded and verified
# Files already downloaded and verified
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          18,432
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#            Dropout-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#              ReLU-10           [-1, 64, 32, 32]               0
#           Dropout-11           [-1, 64, 32, 32]               0
#            Conv2d-12          [-1, 128, 32, 32]           1,280
#            Conv2d-13           [-1, 32, 32, 32]           4,128
# depthwise_separable_conv-14           [-1, 32, 32, 32]               0
#       BatchNorm2d-15           [-1, 32, 32, 32]              64
#              ReLU-16           [-1, 32, 32, 32]               0
#           Dropout-17           [-1, 32, 32, 32]               0
#         MaxPool2d-18           [-1, 32, 16, 16]               0
#            Conv2d-19           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#              ReLU-21           [-1, 64, 16, 16]               0
#            Conv2d-22           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-23           [-1, 64, 16, 16]             128
#              ReLU-24           [-1, 64, 16, 16]               0
#           Dropout-25           [-1, 64, 16, 16]               0
#            Conv2d-26           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-27           [-1, 64, 16, 16]             128
#              ReLU-28           [-1, 64, 16, 16]               0
#           Dropout-29           [-1, 64, 16, 16]               0
#            Conv2d-30          [-1, 128, 16, 16]           1,280
#            Conv2d-31           [-1, 64, 16, 16]           8,256
# depthwise_separable_conv-32           [-1, 64, 16, 16]               0
#       BatchNorm2d-33           [-1, 64, 16, 16]             128
#              ReLU-34           [-1, 64, 16, 16]               0
#           Dropout-35           [-1, 64, 16, 16]               0
#         MaxPool2d-36             [-1, 64, 8, 8]               0
#            Conv2d-37             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-38             [-1, 64, 8, 8]             128
#              ReLU-39             [-1, 64, 8, 8]               0
#            Conv2d-40             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-41             [-1, 64, 8, 8]             128
#              ReLU-42             [-1, 64, 8, 8]               0
#            Conv2d-43             [-1, 64, 6, 6]          36,864
#       BatchNorm2d-44             [-1, 64, 6, 6]             128
#              ReLU-45             [-1, 64, 6, 6]               0
#           Dropout-46             [-1, 64, 6, 6]               0
#         AvgPool2d-47             [-1, 64, 1, 1]               0
#            Conv2d-48             [-1, 32, 1, 1]           2,048
#       BatchNorm2d-49             [-1, 32, 1, 1]              64
#              ReLU-50             [-1, 32, 1, 1]               0
#            Linear-51                   [-1, 10]             330
# ================================================================
# Total params: 224,010
# Trainable params: 224,010
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 9.60
# Params size (MB): 0.85
# Estimated Total Size (MB): 10.47
# ----------------------------------------------------------------

# %%
trainNet.visulaize_dataset()

# %%
trainNet.start()
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# EPOCH : 1
# loss=4.554064750671387 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.36it/s]
#   TRAIN avg loss: 0.0654 train acc: 52.7200
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 1.1701 test acc: 58.2200
#
#
# EPOCH : 2
# loss=3.263911247253418 batch_id=781: 100%|██████████| 782/782 [00:31<00:00, 25.03it/s]
#   TRAIN avg loss: 0.0516 train acc: 68.9480
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.9322 test acc: 67.7900
#
#
# EPOCH : 3
# loss=3.190695285797119 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.27it/s]
#   TRAIN avg loss: 0.0459 train acc: 74.7080
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.7775 test acc: 72.9600
#
#
# EPOCH : 4
# loss=2.3744328022003174 batch_id=781: 100%|██████████| 782/782 [00:31<00:00, 25.08it/s]
#   TRAIN avg loss: 0.0425 train acc: 77.5340
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.7831 test acc: 72.7700
#
#
# EPOCH : 5
# loss=3.011868953704834 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.58it/s]
#   TRAIN avg loss: 0.0400 train acc: 79.2540
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.7634 test acc: 73.6700
#
#
# EPOCH : 6
# loss=2.32083797454834 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.33it/s]
#   TRAIN avg loss: 0.0378 train acc: 80.6520
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.7091 test acc: 75.2000
#
#
# EPOCH : 7
# loss=1.8021678924560547 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.30it/s]
#   TRAIN avg loss: 0.0361 train acc: 81.7820
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.7425 test acc: 74.6900
#
#
# EPOCH : 8
# loss=2.3191709518432617 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.42it/s]
#   TRAIN avg loss: 0.0306 train acc: 87.4100
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4745 test acc: 84.2400
#
#
# EPOCH : 9
# loss=1.6471830606460571 batch_id=781: 100%|██████████| 782/782 [00:31<00:00, 25.16it/s]
#   TRAIN avg loss: 0.0288 train acc: 88.9960
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4524 test acc: 85.1000
#
#
# EPOCH : 10
# loss=2.2756056785583496 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.39it/s]
#   TRAIN avg loss: 0.0277 train acc: 89.9240
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4514 test acc: 85.1100
#
#
# EPOCH : 11
# loss=1.7818526029586792 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.40it/s]
#   TRAIN avg loss: 0.0270 train acc: 90.3200
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4562 test acc: 84.5100
#
#
# EPOCH : 12
# loss=2.4140992164611816 batch_id=781: 100%|██████████| 782/782 [00:31<00:00, 25.12it/s]
#   TRAIN avg loss: 0.0263 train acc: 90.8140
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4469 test acc: 84.9700
#
#
# EPOCH : 13
# loss=1.4250257015228271 batch_id=781: 100%|██████████| 782/782 [00:31<00:00, 25.21it/s]
#   TRAIN avg loss: 0.0256 train acc: 91.1760
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4575 test acc: 84.7400
#
#
# EPOCH : 14
# loss=2.3144497871398926 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.49it/s]
#   TRAIN avg loss: 0.0249 train acc: 91.6760
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4706 test acc: 84.5900
#
#
# EPOCH : 15
# loss=1.3794238567352295 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.41it/s]
#   TRAIN avg loss: 0.0237 train acc: 92.9460
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4627 test acc: 84.9300
#
#
# EPOCH : 16
# loss=2.4313979148864746 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.40it/s]
#   TRAIN avg loss: 0.0235 train acc: 93.2560
#   0%|          | 0/782 [00:00<?, ?it/s]
#   Best Model Saved!!!
#
#
#
#   TEST avg loss: 0.4401 test acc: 85.6600
#
#
# EPOCH : 17
# loss=1.1407244205474854 batch_id=781: 100%|██████████| 782/782 [00:31<00:00, 25.22it/s]
#   TRAIN avg loss: 0.0234 train acc: 93.2660
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4582 test acc: 84.8900
#
#
# EPOCH : 18
# loss=1.71128249168396 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.46it/s]
#   TRAIN avg loss: 0.0232 train acc: 93.4080
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4435 test acc: 85.5400
#
#
# EPOCH : 19
# loss=1.8308138847351074 batch_id=781: 100%|██████████| 782/782 [00:31<00:00, 24.96it/s]
#   TRAIN avg loss: 0.0231 train acc: 93.5140
#   0%|          | 0/782 [00:00<?, ?it/s]
#   TEST avg loss: 0.4434 test acc: 85.4800
#
#
# EPOCH : 20
# loss=1.484538197517395 batch_id=781: 100%|██████████| 782/782 [00:30<00:00, 25.49it/s]
#   TRAIN avg loss: 0.0231 train acc: 93.4880
#   TEST avg loss: 0.4507 test acc: 85.3000

# %%
from main import PostAnalysis

# %%
a = PostAnalysis(config_file)
# Out:
# Number of GPU's available : 1
# GPU device name : Tesla P4
# Files already downloaded and verified
# Files already downloaded and verified
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          18,432
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#            Dropout-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#              ReLU-10           [-1, 64, 32, 32]               0
#           Dropout-11           [-1, 64, 32, 32]               0
#            Conv2d-12          [-1, 128, 32, 32]           1,280
#            Conv2d-13           [-1, 32, 32, 32]           4,128
# depthwise_separable_conv-14           [-1, 32, 32, 32]               0
#       BatchNorm2d-15           [-1, 32, 32, 32]              64
#              ReLU-16           [-1, 32, 32, 32]               0
#           Dropout-17           [-1, 32, 32, 32]               0
#         MaxPool2d-18           [-1, 32, 16, 16]               0
#            Conv2d-19           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#              ReLU-21           [-1, 64, 16, 16]               0
#            Conv2d-22           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-23           [-1, 64, 16, 16]             128
#              ReLU-24           [-1, 64, 16, 16]               0
#           Dropout-25           [-1, 64, 16, 16]               0
#            Conv2d-26           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-27           [-1, 64, 16, 16]             128
#              ReLU-28           [-1, 64, 16, 16]               0
#           Dropout-29           [-1, 64, 16, 16]               0
#            Conv2d-30          [-1, 128, 16, 16]           1,280
#            Conv2d-31           [-1, 64, 16, 16]           8,256
# depthwise_separable_conv-32           [-1, 64, 16, 16]               0
#       BatchNorm2d-33           [-1, 64, 16, 16]             128
#              ReLU-34           [-1, 64, 16, 16]               0
#           Dropout-35           [-1, 64, 16, 16]               0
#         MaxPool2d-36             [-1, 64, 8, 8]               0
#            Conv2d-37             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-38             [-1, 64, 8, 8]             128
#              ReLU-39             [-1, 64, 8, 8]               0
#            Conv2d-40             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-41             [-1, 64, 8, 8]             128
#              ReLU-42             [-1, 64, 8, 8]               0
#            Conv2d-43             [-1, 64, 6, 6]          36,864
#       BatchNorm2d-44             [-1, 64, 6, 6]             128
#              ReLU-45             [-1, 64, 6, 6]               0
#           Dropout-46             [-1, 64, 6, 6]               0
#         AvgPool2d-47             [-1, 64, 1, 1]               0
#            Conv2d-48             [-1, 32, 1, 1]           2,048
#       BatchNorm2d-49             [-1, 32, 1, 1]              64
#              ReLU-50             [-1, 32, 1, 1]               0
#            Linear-51                   [-1, 10]             330
# ================================================================
# Total params: 224,010
# Trainable params: 224,010
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 9.60
# Params size (MB): 0.85
# Estimated Total Size (MB): 10.47
# ----------------------------------------------------------------

# %%
a.show_validation_graph()

# %%
a.show_misclassified_images()

# %%
a.show_per_class_accuracy()
# Out:
# plane		86.500000
# car		92.699997
# bird		77.099998
# cat		71.800003
# deer		83.500000
# dog		76.099998
# frog		88.500000
# horse		88.800003
# ship		91.699997
# truck		91.199997
