# %%
import os
os.chdir("./drive/My Drive/EVA/Session13")

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.1+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
# !ls
# Out:
# YoloV3	YoloV3Sample.ipynb

# %%
cd YoloV3/
# Out:
# /content/drive/My Drive/EVA/Session13/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	    train_batch0.png
#  cfg		   output_video   runs		    train.py
#  data		   __pycache__	  source_video	   'ubdivisions=1'
#  detect.py	   README.md	  test_batch0.png   utils
#  models.py	   results.json   test.py	    vim.exe.stackdump
#  out_out	   results.png	  ting		    weights

# %%
# !mkdir weights

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 120 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=120, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-07-04 09:49:34.423071: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (558 found, 0 missing, 2 empty, 0 duplicate, for 560 images): 100% 560/560 [00:00<00:00, 670.53it/s]
# Caching images (0.4GB): 100% 560/560 [00:03<00:00, 146.33it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/560 data/customdata/images/File00001.jpg: 512x512 1 deadpools, Done. (0.019s)
# image 2/560 data/customdata/images/File00002.jpg: 512x512 1 deadpools, Done. (0.019s)
# image 3/560 data/customdata/images/File00003.jpg: 512x512 1 deadpools, Done. (0.019s)
# image 4/560 data/customdata/images/File00004.jpg: 512x512 1 deadpools, Done. (0.019s)
# image 5/560 data/customdata/images/File00005.jpg: 512x512 1 deadpools, Done. (0.019s)
# ...

# %%
# !ls out_out

# %%
Image(filename='out_out/File00550.jpg', width=600)

# %%
# !python detect.py --conf-thres 0.4 --output "output_video" --source "source_video"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.4, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output_video', save_txt=False, source='source_video', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/4179) source_video/Deadpool - Red Band Trailer [HD] - 20th Century FOX.mp4: 320x512 Done. (0.017s)
# video 1/1 (2/4179) source_video/Deadpool - Red Band Trailer [HD] - 20th Century FOX.mp4: 320x512 Done. (0.016s)
# video 1/1 (3/4179) source_video/Deadpool - Red Band Trailer [HD] - 20th Century FOX.mp4: 320x512 Done. (0.016s)
# video 1/1 (4/4179) source_video/Deadpool - Red Band Trailer [HD] - 20th Century FOX.mp4: 320x512 Done. (0.017s)
# ...
